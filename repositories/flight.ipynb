# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading csv file

# %%
file=pd.read_csv(r'C:\Users\User\Downloads\Airline_customer_satisfaction.csv')

# %%
# applying all basic functions and attributes one by one

# %%
file.size
# Out:
# 2857360

# %%
file.tail()
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 129875             1731             5                                  5
# 129876             2087             2                                  3
# 129877             2320             3                                  0
# 129878             2450             3                                  2
# 129879             4307             3                                  4
#
#         Food and drink  Gate location  ...  Online support  \
# ...

# %%
file.head()
# Out:
#   satisfaction   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  Gate location  ...  Online support  Ease of Online booking  \
# 0               0              2  ...               2                       3
# ...

# %%
print(file.shape)
print(file.shape[0])
print(file.shape[1])
print(file.info)
print(file.describe)
# Out:
# (129880, 22)
# 129880
# 22
# <bound method DataFrame.info of         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
# ...

# %%
# fetching rows and columns

# %%
# fetching one column
print(file['Flight Distance'],"\n\n\n")
#fetching multi columns
print(file[['Flight Distance','Seat comfort']],"\n\n\n")
#fetching 1st row
print(file.iloc[0],"\n\n\n")
#fetching 2nd and 3rd row
print(file.iloc[1:3],"\n\n\n")
#fetching particular rows
print(file.iloc[[1,3,6]])
# Out:
# 0          265
# 1         2464
# 2         2138
# 3          623
# 4          354
#           ...
# 129875    1731
# 129876    2087
# 129877    2320
# 129878    2450
# 129879    4307
# Name: Flight Distance, Length: 129880, dtype: int64
#
#
#
#         Flight Distance  Seat comfort
# 0                   265             0
# 1                  2464             0
# 2                  2138             0
# 3                   623             0
# 4                   354             0
# ...                 ...           ...
# 129875             1731             5
# 129876             2087             2
# 129877             2320             3
# 129878             2450             3
# 129879             4307             3
#
# [129880 rows x 2 columns]
#
#
#
# satisfaction                               satisfied
# Customer Type                         Loyal Customer
# Age                                               65
# Type of Travel                       Personal Travel
# ...

# %%
# filtering dataframe on a condition
#printing details of customers of business class
mask=file['Class']=='Business'
print(file[mask],"\n\n\n")
#printing no. of customers in Business class
print(file[mask].shape[0],"\n\n\n")
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 8          satisfied     Loyal Customer   56  Personal Travel  Business
# 17         satisfied     Loyal Customer   52  Personal Travel  Business
# 23         satisfied     Loyal Customer   53  Personal Travel  Business
# 48         satisfied     Loyal Customer   31  Personal Travel  Business
# ...              ...                ...  ...              ...       ...
# 129844  dissatisfied  disloyal Customer   70  Personal Travel  Business
# 129847  dissatisfied  disloyal Customer   20  Personal Travel  Business
# 129853  dissatisfied  disloyal Customer   14  Personal Travel  Business
# 129856  dissatisfied  disloyal Customer   53  Personal Travel  Business
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
# finding different categories of a given column no. of rows having each category
print(file['Class'].value_counts(),"\n\n\n")
#plotting no. of customers in different class using bar graph
file['Class'].value_counts().plot(kind='bar')
# Out:
# Class
# Business    62160
# Eco         58309
# Eco Plus     9411
# Name: count, dtype: int64
# <Axes: xlabel='Class'>

# %%
#plotting no. of customers in different class using pie chart in pandas 
file['Class'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#plotting no. of customers in different class in the form of pie chart using matplotlib....

plt.pie(file['Class'].value_counts(),labels=(file['Class'].value_counts()).index,autopct='%1.0f%%')
plt.show()

# %%
# sorting
file2=file
file2.sort_values('Flight Distance',ascending=True,inplace=True)
print(file2.head(100).iloc[:,0:6])
# Out:
#         satisfaction   Customer Type  Age   Type of Travel     Class  \
# 113768     satisfied  Loyal Customer   37  Business travel  Business
# 12848      satisfied  Loyal Customer   66  Personal Travel       Eco
# 859        satisfied  Loyal Customer   65  Personal Travel       Eco
# 66546   dissatisfied  Loyal Customer   65  Business travel       Eco
# 16197      satisfied  Loyal Customer   63  Personal Travel       Eco
# ...              ...             ...  ...              ...       ...
# 89287      satisfied  Loyal Customer   66  Business travel  Business
# 84125   dissatisfied  Loyal Customer   62  Business travel  Eco Plus
# 38081      satisfied  Loyal Customer   61  Personal Travel  Business
# 89165      satisfied  Loyal Customer   60  Business travel  Business
# 124829     satisfied  Loyal Customer   60  Business travel  Eco Plus
#
#         Flight Distance
# 113768               50
# 12848                50
# 859                  50
# 66546                50
# ...

# %%
#sorting wrt multi cols
file2.sort_values(['Flight Distance','Age'],ascending=[True,True],inplace=True)
print(file2.head(10).iloc[:,0:6])
# Out:
#         satisfaction   Customer Type  Age   Type of Travel     Class  \
# 113768     satisfied  Loyal Customer   37  Business travel  Business
# 96599      satisfied  Loyal Customer   39  Business travel  Business
# 102381     satisfied  Loyal Customer   43  Business travel  Business
# 113179     satisfied  Loyal Customer   43  Business travel  Business
# 65089      satisfied  Loyal Customer   46  Business travel  Business
# 1403       satisfied  Loyal Customer   47  Personal Travel       Eco
# 109327     satisfied  Loyal Customer   50  Business travel  Business
# 116983     satisfied  Loyal Customer   52  Business travel  Business
# 760        satisfied  Loyal Customer   53  Personal Travel       Eco
# 71215   dissatisfied  Loyal Customer   53  Business travel       Eco
#
#         Flight Distance
# 113768               50
# 96599                50
# 102381               50
# 113179               50
# 65089                50
# 1403                 50
# 109327               50
# ...

# %%
file2=file
print(file2.groupby('Class').head(7),"\n\n\n\n")
print(file2)
# Out:
#         satisfaction   Customer Type  Age   Type of Travel     Class  \
# 113768     satisfied  Loyal Customer   37  Business travel  Business
# 96599      satisfied  Loyal Customer   39  Business travel  Business
# 102381     satisfied  Loyal Customer   43  Business travel  Business
# 113179     satisfied  Loyal Customer   43  Business travel  Business
# 65089      satisfied  Loyal Customer   46  Business travel  Business
# 1403       satisfied  Loyal Customer   47  Personal Travel       Eco
# 109327     satisfied  Loyal Customer   50  Business travel  Business
# 116983     satisfied  Loyal Customer   52  Business travel  Business
# 760        satisfied  Loyal Customer   53  Personal Travel       Eco
# 71215   dissatisfied  Loyal Customer   53  Business travel       Eco
# 30815   dissatisfied  Loyal Customer   54  Personal Travel  Eco Plus
# 1652       satisfied  Loyal Customer   55  Personal Travel  Eco Plus
# 11913      satisfied  Loyal Customer   59  Personal Travel       Eco
# ...
