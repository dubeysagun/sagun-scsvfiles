# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading csv file 
file=pd.read_csv(r'C:\Users\User\Downloads\insurance.csv')

# %%
# applying all basic functions and attributes one by one
print(file.size,"\n\n\n")
print(file.head(),"\n\n\n")
print(file.shape,"\n\n\n")
print(file.shape[0],"\n\n\n")
print(file.shape[1],"\n\n\n")
print(file.info,"\n\n\n")
print(file.describe,"\n\n\n")
file.head()
# Out:
# 9366
#
#
#
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
#
#
#
# (1338, 7)
#
#
#
# 1338
#
#
#
# 7
#
#
#
# <bound method DataFrame.info of       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# ...

# %%
# fetching one column
print(file['charges'],"\n\n\n")
#fetching multi columns
print(file[['region','charges']],"\n\n\n")
#fetching 1st row
print(file.iloc[0],"\n\n\n")
#fetching 2nd and 3rd row
print(file.iloc[1:3],"\n\n\n")
#fetching particular rows
print(file.iloc[[1,3,6]])
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64
#
#
#
#          region      charges
# 0     southwest  16884.92400
# 1     southeast   1725.55230
# 2     southeast   4449.46200
# 3     northwest  21984.47061
# 4     northwest   3866.85520
# ...         ...          ...
# 1333  northwest  10600.54830
# 1334  northeast   2205.98080
# 1335  southeast   1629.83350
# 1336  southwest   2007.94500
# 1337  northwest  29141.36030
#
# [1338 rows x 2 columns]
#
#
#
# age                19
# sex            female
# bmi              27.9
# children            0
# smoker            yes
# region      southwest
# charges     16884.924
# Name: 0, dtype: object
#
#
#
#    age   sex    bmi  children smoker     region    charges
# ...

# %%
# filtering dataframe on a condition
#printing details of smokers of northwest 
mask=file['region']=='northwest'
print(file[mask],"\n\n\n")
#printing no. of  smokers in northwest 
print(file[mask].shape[0],"\n\n\n")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 7      37  female  27.740         3     no  northwest   7281.50560
# 9      60  female  25.840         0     no  northwest  28923.13692
# 24     37    male  28.025         2     no  northwest   6203.90175
# ...   ...     ...     ...       ...    ...        ...          ...
# 1319   39  female  26.315         2     no  northwest   7201.70085
# 1320   31    male  31.065         3     no  northwest   5425.02335
# 1324   31    male  25.935         1     no  northwest   4239.89265
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [325 rows x 7 columns]
#
#
#
# 325

# %%
# finding different categories of a given column and no. of rows having each category
print(file['region'].value_counts(),"\n\n\n")
#plotting no. of smokers in different regions  using bar graph
file['region'].value_counts().plot(kind='bar')
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64
# <Axes: xlabel='region'>

# %%
#plotting  using pie chart in pandas 
file['region'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#plotting no. of smokers in different regions  in the form of pie chart using matplotlib....

plt.pie(file['region'].value_counts(),labels=(file['region'].value_counts()).index,autopct='%1.0f%%')
plt.show()

# %%
# sorting 
file2=file[file['smoker']=='yes']# we've got a df of smokers
file2.sort_values(['age'],inplace=True)
file2
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13972\1285015149.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file2.sort_values(['age'],inplace=True)
#       age     sex     bmi  children smoker     region      charges
# 759    18    male  38.170         0    yes  southeast  36307.79830
# 161    18  female  36.850         0    yes  southeast  36149.48350
# 623    18    male  33.535         0    yes  northeast  34617.84065
# 1282   18  female  21.660         0    yes  northeast  14283.45940
# 803    18  female  42.240         0    yes  southeast  38792.68560
# ...   ...     ...     ...       ...    ...        ...          ...
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 890    64  female  26.885         0    yes  northwest  29330.98315
# ...

# %%
x=file2.groupby(['age'])
# printing no. of smokers in each age group
print(x.size(),'\n\n')
#to print first row of each age group
print(x.first(),"\n\n")
print(x.groups)# output will be a dictionary with key as age group and values as list of indices in that age grp
# Out:
# age
# 18    12
# 19    18
# 20     9
# 21     2
# 22     6
# 23     7
# 24     6
# 25     5
# 26     3
# 27     9
# 28     3
# 29     6
# 30     9
# 31     5
# 32     5
# 33     6
# 34     5
# 35     5
# 36     6
# 37     9
# 38     2
# 39     6
# 40     5
# 41     2
# 42     8
# 43    12
# 44     6
# 45     5
# 46     5
# 47    10
# 48     5
# 49     4
# 50     4
# 51     6
# 52     6
# 53     5
# 54     5
# 55     2
# 56     4
# 57     4
# 58     1
# 59     4
# 60     5
# 61     6
# 62     4
# 63     5
# 64     7
# dtype: int64
#
#
#         sex     bmi  children smoker     region      charges
# age
# 18     male  38.170         0    yes  southeast  36307.79830
# 19   female  27.900         0    yes  southwest  16884.92400
# 20     male  28.025         1    yes  northwest  17560.37975
# 21     male  25.700         4    yes  southwest  17942.10600
# 22     male  37.620         1    yes  southeast  37165.16380
# 23   female  32.780         2    yes  southeast  36021.01120
# ...

# %%
# to get a dataframe with all the rows of a particular group
y=file2.groupby('sex')
df=y.get_group('female')# here we have got a df with all the rows inside the female sex group
print(df.head(3))
# Out:
#       age     sex    bmi  children smoker     region     charges
# 161    18  female  36.85         0    yes  southeast  36149.4835
# 1282   18  female  21.66         0    yes  northeast  14283.4594
# 803    18  female  42.24         0    yes  southeast  38792.6856

# %%
#group wise sum of all the numerical columns and string values get concatenated
y.sum()
# Out:
#          age       bmi  children  \
# sex
# female  4440  3404.950       116
# male    6113  5009.165       189
#
#                                                    smoker  \
# sex
# female  yesyesyesyesyesyesyesyesyesyesyesyesyesyesyesy...
# male    yesyesyesyesyesyesyesyesyesyesyesyesyesyesyesy...
#
#                                                    region       charges
# sex
# female  southeastnortheastsoutheastsoutheastsouthwestn...  3.528085e+06
# male    southeastnortheastnortheastnortheastnortheastn...  5.253679e+06

# %%
y['age'].mean().sort_values(ascending=True)
#it gives the mean age of smokers in each sex group in asecnding order of means
# Out:
# sex
# male      38.446541
# female    38.608696
# Name: age, dtype: float64

# %%
# printing top 5 smokers age group acc to no. of smokers in that group
x['children'].sum().sort_values(ascending=False).head()
# Out:
# age
# 43    18
# 30    17
# 47    14
# 39    12
# 37    11
# Name: children, dtype: int64

# %%
file.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# printing region wise no. of smokers in ascending order
file2.groupby('region')['children'].sum().sort_values(ascending=True)
# Out:
# region
# northeast    70
# southwest    70
# northwest    74
# southeast    91
# Name: children, dtype: int64

# %%
file.head(22)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
# applying linear regression on age and charges columns of this data....
x=file.iloc[:,0:1]
y=file.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=lr.predict(x_test)

# %%
prediction[0:22]
# Out:
# array([ 9246.7700598 , 17254.05695155, 16002.91837472,  7995.63148296,
#        14501.55208251, 13250.41350568,  9496.99777517,  7995.63148296,
#        19255.87867449, 13250.41350568, 18004.74009765,  7995.63148296,
#        13500.64122104,  7995.63148296, 15502.46294398, 18254.96781302,
#        10998.36406737, 11248.59178274, 11999.27492884,  7995.63148296,
#        17754.51238229,  8746.31462906])

# %%
y_test.iloc[0:22]
# Out:
# 17       2395.17155
# 1091    11286.53870
# 273      9617.66245
# 270      1719.43630
# 874      8891.13950
# 790      5662.22500
# 957     12609.88702
# 492      2196.47320
# 1125    14254.60820
# 794      7209.49180
# 575     12222.89830
# 571      2219.44510
# 235     19444.26580
# 940      1121.87390
# 658     26392.26029
# 532     12925.88600
# 101      3645.08940
# 1190     5327.40025
# 142     18972.49500
# 471      2203.47185
# 457     11840.77505
# 363      2597.77900
# Name: charges, dtype: float64

# %%
plt.scatter(x,y)
plt.plot(x_train,lr.predict(x_train),color='red')
